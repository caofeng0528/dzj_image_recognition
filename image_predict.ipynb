# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
import seaborn as sns
import os
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import matplotlib.image as mpimg
import warnings
sns.set()
# %matplotlib inline
warnings.filterwarnings("ignore")

size  = 150
channels = 3
batch = 128
epochs = 15

datagen = ImageDataGenerator(rescale=1./255,
                             zoom_range=0.2,
                             width_shift_range=.2, height_shift_range=.2,
                             rotation_range=30,
                             brightness_range=[0.8, 1.2],
                             horizontal_flip=True)

datagenValidation = ImageDataGenerator(rescale=1./255)
Model = tf.keras.models.load_model('D:/image/dataset/image_best_model.hdf5')
filenames = os.listdir("D:/image/dataset/image_test1")
df_test = pd.DataFrame({'Image':filenames})
df_test
# Out:
#             Image
# 0    bhg. (1).jpg
# 1    bhg. (1).png
# 2   bhg. (29).jpg
# 3   bhg. (29).png
# 4   bhg. (37).jpg
# 5    bhg. (4).jpg
# 6   bhg. (40).png
# 7   bhg. (44).jpg
# 8   bhg. (47).png
# 9   bhg. (48).jpg
# 10  bhg. (49).jpg
# 11  bhg. (49).png
# 12  bhg. (50).jpg
# 13  bhg. (52).jpg
# 14  bhg. (52).png
# 15  bhg. (57).jpg
# 16  bhg. (58).jpg
# 17  bhg. (59).jpg
# 18  bhg. (61).jpg
# 19  bhg. (63).jpg
# 20  bhg. (63).png
# 21  bhg. (66).jpg
# 22  bhg. (68).jpg
# 23   bhg. (7).jpg
# 24  bhg. (71).jpg
# 25  bhg. (74).jpg
# 26  bhg. (75).jpg
# 27  bhg. (76).jpg
# 28  bhg. (79).jpg
# 29  bhg. (84).jpg
# 30  bhg. (87).jpg
# 31  bhg. (88).jpg
# 32    hg. (1).jpg
# 33   hg. (10).jpg
# 34   hg. (11).jpg
# 35   hg. (12).jpg
# 36   hg. (13).jpg
# 37    hg. (5).jpg
# 38    hg. (5).png
# 39   hg. (53).jpg
# 40    hg. (6).png
# 41   hg. (61).jpg
# 42   hg. (62).jpg
# 43   hg. (63).jpg
# 44   hg. (68).jpg
# 45    hg. (8).jpg
# 46    hg. (9).jpg

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
import seaborn as sns
import os
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import matplotlib.image as mpimg
import warnings
sns.set()
# %matplotlib inline
warnings.filterwarnings("ignore")

size  = 150
channels = 3
batch = 128
epochs = 15

datagen = ImageDataGenerator(rescale=1./255,
                             zoom_range=0.2,
                             width_shift_range=.2, height_shift_range=.2,
                             rotation_range=30,
                             brightness_range=[0.8, 1.2],
                             horizontal_flip=True)

datagenValidation = ImageDataGenerator(rescale=1./255)
Model = tf.keras.models.load_model('D:/image/dataset/image_best_model.hdf5')
filenames = os.listdir("D:/image/dataset/image_test1")
df_test = pd.DataFrame({'Image':filenames})
df_test
# Out:
#             Image
# 0    bhg. (1).jpg
# 1    bhg. (1).png
# 2   bhg. (29).jpg
# 3   bhg. (29).png
# 4   bhg. (37).jpg
# 5    bhg. (4).jpg
# 6   bhg. (40).png
# 7   bhg. (44).jpg
# 8   bhg. (47).png
# 9   bhg. (48).jpg
# 10  bhg. (49).jpg
# 11  bhg. (49).png
# 12  bhg. (50).jpg
# 13  bhg. (52).jpg
# 14  bhg. (52).png
# 15  bhg. (57).jpg
# 16  bhg. (58).jpg
# 17  bhg. (59).jpg
# 18  bhg. (61).jpg
# 19  bhg. (63).jpg
# 20  bhg. (63).png
# 21  bhg. (66).jpg
# 22  bhg. (68).jpg
# 23   bhg. (7).jpg
# 24  bhg. (71).jpg
# 25  bhg. (74).jpg
# 26  bhg. (75).jpg
# 27  bhg. (76).jpg
# 28  bhg. (79).jpg
# 29  bhg. (84).jpg
# 30  bhg. (87).jpg
# 31  bhg. (88).jpg
# 32    hg. (1).jpg
# 33   hg. (10).jpg
# 34   hg. (11).jpg
# 35   hg. (12).jpg
# 36   hg. (13).jpg
# 37    hg. (5).jpg
# 38    hg. (5).png
# 39   hg. (53).jpg
# 40    hg. (6).png
# 41   hg. (61).jpg
# 42   hg. (62).jpg
# 43   hg. (63).jpg
# 44   hg. (68).jpg
# 45    hg. (8).jpg
# 46    hg. (9).jpg

# %%
 X_test = datagenValidation.flow_from_dataframe(
            df_test, 
            directory="D:/image/dataset/image_test1", 
            x_col='Image',
            y_col=None,
            class_mode=None,
            target_size= (size,size),
            batch_size=batch,
            shuffle=False)
# Out:
# Found 47 validated image filenames.

# %%
y_pred = Model.predict(X_test)
y_pred = np.where(y_pred > .5, "yes", "no")
y_pred
# Out:
# array([['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes']], dtype='<U3')

# %%
plt.figure(figsize=(15,15))

for i in range(47):
    plt.subplot(5,10,i+1)
    plt.imshow(X_test[0][i])
    plt.xlabel(y_pred[i])
    
plt.show()

# %%
yp = pd.DataFrame(y_pred)
yp.columns=["predict"]
yp
# Out:
#    predict
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
# 5       no
# 6       no
# 7       no
# 8       no
# 9       no
# 10      no
# 11      no
# 12      no
# 13      no
# 14      no
# 15      no
# 16      no
# 17     yes
# 18      no
# 19      no
# 20     yes
# 21      no
# 22      no
# 23      no
# 24      no
# 25     yes
# 26      no
# 27      no
# 28      no
# 29      no
# 30      no
# 31      no
# 32     yes
# 33     yes
# 34     yes
# 35     yes
# 36     yes
# 37      no
# 38     yes
# 39     yes
# 40     yes
# 41     yes
# 42      no
# 43     yes
# 44      no
# 45     yes
# 46     yes

# %%
pd.concat([df_test,yp],axis=1)
# Out:
#             Image predict
# 0    bhg. (1).jpg      no
# 1    bhg. (1).png      no
# 2   bhg. (29).jpg      no
# 3   bhg. (29).png      no
# 4   bhg. (37).jpg      no
# 5    bhg. (4).jpg      no
# 6   bhg. (40).png      no
# 7   bhg. (44).jpg      no
# 8   bhg. (47).png      no
# 9   bhg. (48).jpg      no
# 10  bhg. (49).jpg      no
# 11  bhg. (49).png      no
# 12  bhg. (50).jpg      no
# 13  bhg. (52).jpg      no
# 14  bhg. (52).png      no
# 15  bhg. (57).jpg      no
# 16  bhg. (58).jpg      no
# 17  bhg. (59).jpg     yes
# 18  bhg. (61).jpg      no
# 19  bhg. (63).jpg      no
# 20  bhg. (63).png     yes
# 21  bhg. (66).jpg      no
# 22  bhg. (68).jpg      no
# 23   bhg. (7).jpg      no
# 24  bhg. (71).jpg      no
# 25  bhg. (74).jpg     yes
# 26  bhg. (75).jpg      no
# 27  bhg. (76).jpg      no
# 28  bhg. (79).jpg      no
# 29  bhg. (84).jpg      no
# 30  bhg. (87).jpg      no
# 31  bhg. (88).jpg      no
# 32    hg. (1).jpg     yes
# 33   hg. (10).jpg     yes
# ...
